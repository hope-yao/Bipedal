# %%
def three_linked_chain(state, t):
    q1 = state[0]
    q1d = state[1]
    q2 = state[2]
    q2d = state[3]
    q3 = state[4]
    q3d = state[5]
    
    H = np.zeros((3,3))
    H[0,0] = ms*a1**2 + mt*(ls+a2)**2 + (mh+ms+mt)*l**2
    H[0,1] = -(mt*b2+ms*lt) * l * cos(q2-q1)
    H[0,2] = -ms*b1*l * cos(q3-q1)
    H[1,0] = H[0,1]
    H[1,1] = mt*b2**2 + ms*lt**2
    H[1,2] = ms*lt*b1 * cos(q3-q2)
    H[2,0] = H[0,2]
    H[2,1] = H[1,2]
    H[2,2] = ms*b1**2
    
    B = np.zeros((3,3))
    h122 = -(mt*b2+ms*lt) * l * sin(q1-q2)
    h133 = -ms*b1*l * sin(q1-q3)
    h211 = -h122
    h233 = ms*lt*b1 * sin(q3-q2)
    h311 = -h133
    h322 = -h233
    B[0,0] = 0
    B[0,1] = h122 * q2d
    B[0,2] = h133 * q3d
    B[1,0] = h211 * q1d
    B[1,1] = 0
    B[1,2] = h233 * q3d
    B[2,0] = h311 * q1d
    B[2,1] = h322 * q2d
    B[2,2] = 0

    G = np.zeros(3)
    G[0] = -(ms*a1 + mt*(ls+a2) + (mh+ms+mt)*l) * g*sin(q1)
    G[1] = (mt*b2 + ms*lt) * g*sin(q2)
    G[2] = ms*b1*g * sin(q3)
    
    qd = [q1d,q2d,q3d]
    rhs = -np.dot(B,qd) - G
    sol = np.linalg.solve(H,rhs)
    xd = np.zeros_like(state)
    xd[0] = q1d
    xd[1] = sol[0]
    xd[2] = q2d 
    xd[3] = sol[1]
    xd[4] = q3d 
    xd[5] = sol[2]
    
    return xd


    
def two_linked_chain(state, t):
    q1 = state[0]
    q1d = state[1]
    q2 = state[2]
    q2d = state[3]
    
    H = np.zeros((2,2))
    H[0,0] = ms*a1**2 + mt*(ls+a2)**2 + (mh+ms+mt)*l**2
    H[0,1] = -(mt*b2 + ms*(lt+b1))*l *cos(q2-q1)
    H[1,0] = H[0,1]
    H[1,1] = mt*b2**2 + ms*(lt+b1)**2
    
    h = -(mt*b2 + ms*(lt+b1))*l * sin(q1-q2)
    B = np.zeros((2,2))
    B[0,0] = 0
    B[0,1] = h*q2d
    B[1,0] = 0
    B[1,1] = -h*q1d

    G = np.zeros(2)
    G[0] = -(ms*a1 + mt*(ls+a2) + (mh+mt+ms)*l) *g*sin(q1)
    G[1] = (mt*b2 + ms*(lt+b1)) * g*sin(q2)

    qd = [q1d,q2d]
    rhs = -np.dot(B,qd) - G
    sol = np.linalg.solve(H,rhs)

    xd = np.zeros_like(state)
    xd[0] = q1d
    xd[1] = sol[0]
    xd[2] = q2d 
    xd[3] = sol[1]
    xd[4] = q2d 
    xd[5] = sol[1]
    
    return xd

# %%
def heel_strike(state):
    q1 = state[0]
    q2 = state[2]

    alpha = cos(q1-q2)    
    
    Q_r = np.zeros((2,2))
    Q_r[1,1] = 0
    Q_r[1,0] = -ms*a1*(lt+b1) + mt*b2*(ls+a2)
    Q_r[0,1] = Q_r[1,0]
    Q_r[0,0] = Q_r[0,1] + (mh*l + 2*mt*(a2+ls) + ms*a1) * l*cos(alpha)
    
    Q_l = np.zeros((2,2))
    Q_l[1,1] = ms*(lt+b1)**2 + mt*b2**2
    Q_l[1,0] = -(ms*(b1+lt) + mt*b2) * l*cos(alpha)
    Q_l[0,1] = Q_l[1,0] + ms*(b1+lt)**2 + mt*b2**2
    Q_l[0,0] = Q_l[1,0] + (ms+mt+mh)*l**2 + ms*a1**2 + mt*(a2+ls)**2
    
    q_r = [state[1],state[3]]
    rhs = np.dot(Q_r,q_r)
    sol = np.linalg.solve(Q_l,rhs)

    xd = np.zeros_like(state)
    xd[0] = state[2]
    xd[1] = sol[0]
    xd[2] = state[0]
    xd[3] = sol[1]
    xd[4] = state[0]
    xd[5] = sol[1]
    
    return xd

def knee_strike(state):
    q1 = state[0]
    q2 = state[2]
    q3 = state[4]

    alpha = cos(q1-q2)
    beta = cos(q1-q3)
    gamma = cos(q2-q3)
    
    Q_r = np.zeros((2,3))
    Q_r[0,0] = -(ms*lt+mt*b2)*l*cos(alpha) - ms*b1*l*cos(beta) + (mt+ms+mh)*l**2 + ms*a1**2 + mt*(ls+a2)**2
    Q_r[0,1] = -(ms*lt+mt*b2)*l*cos(alpha) + ms*b1*lt*cos(gamma) + mt*b2**2 + ms*lt**2
    Q_r[0,2] = -ms*b1*l*cos(beta) + ms*b1*lt*cos(gamma) + ms*b1**2
    Q_r[1,0] = -(ms*lt+mt*b2)*l*cos(alpha) - ms*b1*l*cos(beta)
    Q_r[1,1] = ms*b1*lt*cos(gamma) + ms*lt**2 + mt*b2**2
    Q_r[1,2] = ms*b1*lt*cos(gamma) + ms*b1**2
    
    Q_l = np.zeros((2,2))
    Q_l[1,1] = ms*(lt+b1)**2 + mt*b2**2
    Q_l[1,0] = -(ms*(b1+lt) + mt*b2) * l*cos(alpha)
    Q_l[0,1] = Q_l[1,0] + ms*(lt+b1)**2 + mt*b2**2
    Q_l[0,0] = Q_l[1,0] + mt*(ls+a2)**2 + (mh+mt+ms)*l**2 + ms*a1**2

    q_r = [state[1],state[3],state[5]]
    rhs = np.dot(Q_r,q_r)
    sol = np.linalg.solve(Q_l,rhs)

    xd = np.zeros_like(state)
    xd[0] = state[1]
    xd[1] = sol[0]
    xd[2] = state[3]
    xd[3] = sol[1]
    xd[4] = state[5]
    xd[5] = sol[1]  # q3d = q2d, thigh and shank binded
     
    return xd

# %%
# Passive Dynamic Walking for bipedal robot 
# % reset

from numpy import sin, cos
import numpy as np
import scipy.integrate as integrate
import math

f = open('out.txt', 'w')

g = 9.8  # acceleration due to gravity, in m/s^2
mt = 0.5  # mass of thigh
ms = 0.05  # mass of shank
mh = 0.5   #mass of hip

a1 = 0.375
b1 = 0.125
a2 = 0.175
b2 = 0.325
lt = a2 + b2  # length of thigh
ls = a1 + b1  # length of shank
l = lt + ls

_gamma = (10)
_alpha = (20)
   
# initial states
q1 = _alpha/2 - _gamma
q1d = 0.0
q2 = _alpha/2 + _gamma
q2d = 0.0
q3 = q2 
q3d = 0.0
  

# initial state
state = np.radians([q1, q1d, q2, q2d, q3, q3d])
print('initial position')
print(np.degrees([state[0],state[2],state[4]]))

ttcosd = []
cnt = 0
dt = 0.005
_time = 0.05 # physical solve time
num_time = 2
_time = num_time * dt
chain_num=3 # starts with three-chain state
while cnt<200:
    print('cnt: ',cnt)
    t = np.arange(0.0, _time, dt)
    if cnt==0:
        tmp = integrate.odeint(three_linked_chain, state, t)
        state = np.insert(tmp[1:len(tmp)+1],[0],state,axis=0)
        print('three linked chain, time: %s <<<' % (cnt*_time))
        print(np.degrees([state[-1,0],state[-1,2],state[-1,4]]))
        cnt += 1
        continue
    # knee strike
    if  (np.max(-(state[-num_time:,2]))>np.radians(_alpha/2-_gamma)*0.9)\
    and (chain_num==3) and (np.min(np.abs(state[-num_time:,2]-state[-num_time:,4]))<np.radians(1)):
        tmp = knee_strike(state[-1])
        chain_num = 2
        print('===============================================knee strike, time: %s' % (cnt*_time))
        print(np.degrees([state[-1,0],state[-1,2],state[-1,4]]))
        continue
    # heel strike
    if (chain_num==2) and cosd<(1): # in degree
        tmp = heel_strike(state[-1])
        chain_num = 3
        print('===============================================heel strike, time: %s' % (cnt*_time))
        print(np.degrees([state[-1,0],state[-1,2],state[-1,4]]))
        # switching nonstance leg and stance leg at this moment
        continue
#         break
    # three linked chain
    if (chain_num==3):
        tmp = integrate.odeint(three_linked_chain, state[-1], t)
        state = np.insert(tmp[1:len(tmp)+1],[0],state,axis=0)
        print('three linked chain, time: %s <<<' % (cnt*_time))
        print(np.degrees([state[-1,0],state[-1,2],state[-1,4]]))
        chain_num = 3
        cnt += 1
    # two linked chain
    if (chain_num==2):
        tmp = integrate.odeint(two_linked_chain, state[-1], t)
        state = np.insert(tmp[1:len(tmp)+1],[0],state,axis=0)            
        print('two linked chain, time: %s <<<' % (cnt*_time))
        print(np.degrees([state[-1,0],state[-1,2],state[-1,4]]))
        chain_num = 2
        cnt += 1
    
    q1 = tmp[:,0]
    q2 = tmp[:,2]
    q3 = tmp[:,4]
    x_h_tmp = -l*sin(q1)
    y_h_tmp = l*cos(q1)
    x_nsk_tmp = x_h_tmp - lt*sin(q2)
    y_nsk_tmp = y_h_tmp - lt*cos(q2)
    x_nsf_tmp = x_nsk_tmp - ls*sin(q3)
    y_nsf_tmp = y_nsk_tmp - ls*cos(q3)
    
    v1 = [(x_nsf_tmp[i],y_nsf_tmp[i]) for i in range(num_time)]
    v2 = [cos(np.radians(_gamma)),-sin(np.radians(_gamma))]
    ab = np.dot(v1, v2)
    cosd = [np.degrees(math.acos( ab[i] / np.linalg.norm((x_nsf_tmp[i],y_nsf_tmp[i])))) for i in range(len(ab))]
    ttcosd = ttcosd + (cosd)
    cosd = min(np.abs(cosd))
    print('cosd: ',cosd)
    print('chain_num: ',chain_num)

q1 = state[:,0]
q2 = state[:,2]
q3 = state[:,4]
x_h = -l*sin(q1)
y_h = l*cos(q1)
x_nsk = x_h - lt*sin(q2)
y_nsk = y_h - lt*cos(q2)
x_nsf = x_nsk - ls*sin(q3)
y_nsf = y_nsk - ls*cos(q3)

x_slop_low = 2 * cos(np.radians(_gamma))
x_slop_up = -x_slop_low
y_slop_low = -2 * sin(np.radians(_gamma))
y_slop_up = -y_slop_low
# Out:
# initial position
# [  0.  20.  20.]
# cnt:  0
# three linked chain, time: 0.0 <<<
# [ -1.55243602e-03   1.99881260e+01   2.00166190e+01]
# cnt:  1
# three linked chain, time: 0.01 <<<
# [ -6.20975229e-03   1.99525146e+01   2.00664053e+01]
# cosd:  179.992084917
# chain_num:  3
# cnt:  2
# three linked chain, time: 0.02 <<<
# [ -1.39719642e-02   1.98931985e+01   2.01491467e+01]
# cosd:  179.982022588
# chain_num:  3
# cnt:  3
# three linked chain, time: 0.03 <<<
# [ -0.02483907  19.81023182  20.26449081]
# cosd:  179.96762405
# chain_num:  3
# cnt:  4
# three linked chain, time: 0.04 <<<
# [ -0.03881098  19.70369038  20.41194617]
# cosd:  179.948585095
# chain_num:  3
# cnt:  5
# three linked chain, time: 0.05 <<<
# [ -0.0558875   19.57367185  20.59088455]
# cosd:  179.924524463
# chain_num:  3
# cnt:  6
# three linked chain, time: 0.06 <<<
# [ -0.0760682   19.42029568  20.80054354]
# cosd:  179.894990807
# chain_num:  3
# cnt:  7
# three linked chain, time: 0.07 <<<
# [ -0.09935231  19.24370317  21.04002977]
# cosd:  179.859470772
# chain_num:  3
# cnt:  8
# three linked chain, time: 0.08 <<<
# [ -0.12573865  19.04405761  21.3083226 ]
# cosd:  179.817397945
# chain_num:  3
# cnt:  9
# three linked chain, time: 0.09 <<<
# [ -0.15522544  18.82154429  21.60427854]
# cosd:  179.768162367
# chain_num:  3
# cnt:  10
# three linked chain, time: 0.1 <<<
# [ -0.18781017  18.57637071  21.92663562]
# cosd:  179.711120533
# chain_num:  3
# cnt:  11
# three linked chain, time: 0.11 <<<
# [ -0.22348942  18.30876665  22.27401882]
# cosd:  179.645605295
# chain_num:  3
# cnt:  12
# three linked chain, time: 0.12 <<<
# [ -0.26225869  18.01898429  22.64494562]
# cosd:  179.570935695
# chain_num:  3
# cnt:  13
# three linked chain, time: 0.13 <<<
# [ -0.30411221  17.7072984   23.03783194]
# cosd:  179.486426377
# chain_num:  3
# cnt:  14
# three linked chain, time: 0.14 <<<
# [ -0.34904268  17.37400647  23.45099838]
# cosd:  179.391396362
# chain_num:  3
# cnt:  15
# three linked chain, time: 0.15 <<<
# [ -0.39704113  17.01942892  23.88267682]
# cosd:  179.28517704
# chain_num:  3
# cnt:  16
# three linked chain, time: 0.16 <<<
# [ -0.44809665  16.64390918  24.33101721]
# cosd:  179.167119182
# chain_num:  3
# cnt:  17
# three linked chain, time: 0.17 <<<
# [ -0.50219615  16.247814    24.79409452]
# cosd:  179.036598909
# chain_num:  3
# cnt:  18
# three linked chain, time: 0.18 <<<
# [ -0.55932416  15.83153346  25.26991605]
# cosd:  178.893022417
# chain_num:  3
# cnt:  19
# three linked chain, time: 0.19 <<<
# [ -0.61946257  15.39548129  25.7564281 ]
# cosd:  178.735829718
# chain_num:  3
# cnt:  20
# three linked chain, time: 0.2 <<<
# [ -0.68259041  14.94009493  26.25152372]
# [ -8.21313582 -24.12795954 -12.44320496]
# cosd:  15.362702774
# chain_num:  3
# cnt:  86
# three linked chain, time: 0.86 <<<
# [ -8.34069186 -24.4240568  -14.81917838]
# cosd:  15.6698309081
# chain_num:  3
# cnt:  87
# three linked chain, time: 0.87 <<<
# [ -8.46800411 -24.70193428 -17.23563306]
# cosd:  16.0451137492
# chain_num:  3
# cnt:  88
# three linked chain, time: 0.88 <<<
# [ -8.59503462 -24.96127647 -19.68977591]
# cosd:  16.4820400145
# chain_num:  3
# cnt:  89
# three linked chain, time: 0.89 <<<
# [ -8.72174215 -25.20176279 -22.1786716 ]
# cosd:  16.9748836897
# chain_num:  3
# cnt:  90
# three linked chain, time: 0.9 <<<
# [ -8.84808265 -25.42306955 -24.69924451]
# cosd:  17.5185423148
# chain_num:  3
# cnt:  91
# ===============================================knee strike, time: 0.91
# [ -8.84808265 -25.42306955 -24.69924451]
# cnt:  91
# two linked chain, time: 0.91 <<<
# [ -8.97426754 -25.62687264 -24.9030476 ]
# cosd:  18.108411841
# chain_num:  2
# cnt:  92
# two linked chain, time: 0.92 <<<
# [ -9.10055805 -25.81501873 -25.09119369]
# cosd:  18.147201766
# chain_num:  2
# cnt:  93
# two linked chain, time: 0.93 <<<
# [ -9.22698409 -25.98744811 -25.26362307]
# cosd:  18.1781116173
# chain_num:  2
# cnt:  94
# two linked chain, time: 0.9400000000000001 <<<
# [ -9.35357689 -26.14411334 -25.4202883 ]
# cosd:  18.2010965307
# chain_num:  2
# cnt:  95
# two linked chain, time: 0.9500000000000001 <<<
# [ -9.48036894 -26.28497925 -25.5611542 ]
# cosd:  18.2161171185
# chain_num:  2
# cnt:  96
# two linked chain, time: 0.96 <<<
# [ -9.60739404 -26.41002305 -25.68619801]
# cosd:  18.222135348
# chain_num:  2
# cnt:  97
# two linked chain, time: 0.97 <<<
# [ -9.73468729 -26.51923443 -25.79540939]
# cosd:  18.2130819114
# chain_num:  2
# cnt:  98
# two linked chain, time: 0.98 <<<
# [ -9.86228508 -26.61261564 -25.8887906 ]
# cosd:  18.1959620807
# chain_num:  2
# cnt:  99
# two linked chain, time: 0.99 <<<
# [ -9.99022512 -26.6901816  -25.96635656]
# cosd:  18.1707644293
# chain_num:  2
# cnt:  100
# two linked chain, time: 1.0 <<<
# [-10.1185465  -26.75196009 -26.02813505]
# cosd:  18.1374832724
# chain_num:  2
# cnt:  101
# two linked chain, time: 1.01 <<<
# [-10.24728966 -26.79799185 -26.07416681]
# cosd:  18.0961187278
# chain_num:  2
# cnt:  102
# two linked chain, time: 1.02 <<<
# [-10.37649651 -26.82833082 -26.10450578]
# cosd:  18.0466767828
# chain_num:  2
# cnt:  103
# two linked chain, time: 1.03 <<<
# [-10.50621042 -26.84304426 -26.11921922]
# cosd:  17.9891693652
# chain_num:  2
# cnt:  104
# two linked chain, time: 1.04 <<<
# [-10.6364763  -26.84221304 -26.118388  ]
# cosd:  17.9236144192
# chain_num:  2
# cnt:  105
# two linked chain, time: 1.05 <<<
# [-10.76734068 -26.82593181 -26.10210677]
# [-24.5804977  -10.13322448  -9.40939944]
# cosd:  2.59725614589
# chain_num:  2
# cnt:  170
# two linked chain, time: 1.7 <<<
# [-24.97887966 -10.02964787  -9.30582283]
# cosd:  2.3462601431
# chain_num:  2
# cnt:  171
# two linked chain, time: 1.71 <<<
# [-25.38626182  -9.94327184  -9.2194468 ]
# cosd:  2.09936315392
# chain_num:  2
# cnt:  172
# two linked chain, time: 1.72 <<<
# [-25.80277558  -9.87437361  -9.15054857]
# cosd:  1.85663813109
# chain_num:  2
# cnt:  173
# two linked chain, time: 1.73 <<<
# [-26.22854976  -9.82319966  -9.09937462]
# cosd:  1.61814396635
# chain_num:  2
# cnt:  174
# two linked chain, time: 1.74 <<<
# [-26.66371069  -9.7899656   -9.06614056]
# cosd:  1.38392535674
# chain_num:  2
# cnt:  175
# two linked chain, time: 1.75 <<<
# [-27.10838227  -9.77485604  -9.051031  ]
# cosd:  1.15401271112
# chain_num:  2
# cnt:  176
# two linked chain, time: 1.76 <<<
# [-27.56268611  -9.77802455  -9.05419951]
# cosd:  0.92842208949
# chain_num:  2
# cnt:  177
# ===============================================heel strike, time: 1.77
# [-27.56268611  -9.77802455  -9.05419951]

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [i*dt for i in range(len(ttcosd))]

plt.plot(x,ttcosd)

plt.show()

# %%
#     f = open('out.txt', 'w')
#     f.write(('state itrnum: '+str(cnt)))
#     f.write(str(state))
#     f.write('\n')

% reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import matplotlib.pyplot as plt
from numpy import random 
import matplotlib.animation as animation

fig = plt.figure()
ax1 = plt.axes(xlim=(-2, 2), ylim=(-2,2))
ax1.grid(True)
plt.xlabel('Longitude')
plt.ylabel('Latitude')

lines = []
lobj = ax1.plot([],[],'o-',lw=2,color="black")[0]
lines.append(lobj)
lobj = ax1.plot([],[],lw=2,color="red")[0]
lines.append(lobj)

time_template = 'time = %.3fs'
time_text = ax1.text(0.05, 0.9, '', transform=ax1.transAxes)

def init():
    for line in lines:
        line.set_data([],[])
    time_text.set_text('')
    return tuple(lines) + (time_text,)

print(len(state))

def animate(i):

    x_bipedal = [0, x_h[i], x_nsk[i], x_nsf[i]]
    y_bipedal = [0, y_h[i], y_nsk[i], y_nsf[i]]
#     x_bipedal = [0, x_h[-10], x_nsk[-10], x_nsf[-10]]
#     y_bipedal = [0, y_h[-10], y_nsk[-10], y_nsf[-10]]

    x_slop = [x_slop_up,x_slop_low,-2]
    y_slop = [y_slop_up,y_slop_low,y_slop_low]

    xlist = [x_bipedal, x_slop]
    ylist = [y_bipedal, y_slop]

    for lnum,line in enumerate(lines):
        line.set_data(xlist[lnum], ylist[lnum]) # set data for each line separately. 
    
    time_text.set_text(time_template % (i*_time))
       
    return tuple(lines) + (time_text,)

print('hello')

# call the animator.  blit=True means only re-draw the parts that have changed.
# ani = animation.FuncAnimation(fig, animate, init_func=init,
#                                frames=300, interval=10, blit=True)

ani = animation.FuncAnimation(fig, animate, np.arange(1, len(state)),
                              interval=50, blit=True, init_func=init)
plt.show()
# ani.save('PDW.mp4', fps=15)
# Out:
# 178
# hello
