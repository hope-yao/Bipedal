# %%
def three_linked_chain(state, t):
    q1 = state[0]
    q1d = state[1]
    q2 = state[2]
    q2d = state[3]
    q3 = state[4]
    q3d = state[5]

    H = np.zeros((3,3))
    H[0,0] = ms*a1**2 + mt*(ls+a2)**2 + (mh+ms+mt)*l**2
    H[0,1] = -(mt*b2+ms*lt) * l * cos(q2-q1)
    H[0,2] = -ms*b1*l * cos(q3-q1)
    H[1,0] = H[0,1]
    H[1,1] = mt*b2**2 + ms*lt**2
    H[1,2] = ms*lt*b1 * cos(q3-q2)
    H[2,0] = H[0,2]
    H[2,1] = H[1,2]
    H[2,2] = ms*b1**2

    B = np.zeros((3,3))
    h122 = -(mt*b2+ms*lt) * l * sin(q1-q2)
    h133 = -ms*b1*l * sin(q1-q3)
    h211 = -h122
    h233 = ms*lt*b1 * sin(q3-q2)
    h311 = -h133
    h322 = -h233
    B[0,0] = 0
    B[0,1] = h122 * q2d
    B[0,2] = h133 * q3d
    B[1,0] = h211 * q1d
    B[1,1] = 0
    B[1,2] = h233 * q3d
    B[2,0] = h311 * q1d
    B[2,1] = h322 * q2d
    B[2,2] = 0

    G = np.zeros(3)
    G[0] = -(ms*a1 + mt*(ls+a2) + (mh+ms+mt)*l) * g*sin(q1)
    G[1] = (mt*b2 + ms*lt) * g*sin(q2)
    G[2] = ms*b1*g * sin(q3)

    qd = [q1d,q2d,q3d]
    rhs = -np.dot(B,qd) - G
    sol = np.linalg.solve(H,rhs)
    xd = np.zeros_like(state)
    xd[0] = q1d
    xd[1] = sol[0]
    xd[2] = q2d
    xd[3] = sol[1]
    xd[4] = q3d
    xd[5] = sol[2]

    return xd



def two_linked_chain(state, t):
    q1 = state[0]
    q1d = state[1]
    q2 = state[2]
    q2d = state[3]

    H = np.zeros((2,2))
    H[0,0] = ms*a1**2 + mt*(ls+a2)**2 + (mh+ms+mt)*l**2
    H[0,1] = -(mt*b2 + ms*(lt+b1))*l *cos(q2-q1)
    H[1,0] = H[0,1]
    H[1,1] = mt*b2**2 + ms*(lt+b1)**2

    h = -(mt*b2 + ms*(lt+b1))*l * sin(q1-q2)
    B = np.zeros((2,2))
    B[0,0] = 0
    B[0,1] = h*q2d
    B[1,0] = 0
    B[1,1] = -h*q1d

    G = np.zeros(2)
    G[0] = -(ms*a1 + mt*(ls+a2) + (mh+mt+ms)*l) *g*sin(q1)
    G[1] = (mt*b2 + ms*(lt+b1)) * g*sin(q2)

    qd = [q1d,q2d]
    rhs = -np.dot(B,qd) - G
    sol = np.linalg.solve(H,rhs)

    xd = np.zeros_like(state)
    xd[0] = q1d
    xd[1] = sol[0]
    xd[2] = q2d
    xd[3] = sol[1]
    xd[4] = q2d
    xd[5] = sol[1]

    return xd


def heel_strike(state):
    q1 = state[0]
    q2 = state[2]

    alpha = cos(q1-q2)

    Q_r = np.zeros((2,2))
    Q_r[1,1] = 0
    Q_r[1,0] = -ms*a1*(lt+b1) + mt*b2*(ls+a2)
    Q_r[0,1] = Q_r[1,0]
    Q_r[0,0] = Q_r[0,1] + (mh*l + 2*mt*(a2+ls) + ms*a1) * l*cos(alpha)

    Q_l = np.zeros((2,2))
    Q_l[1,1] = ms*(lt+b1)**2 + mt*b2**2
    Q_l[1,0] = -(ms*(b1+lt) + mt*b2) * l*cos(alpha)
    Q_l[0,1] = Q_l[1,0] + ms*(b1+lt)**2 + mt*b2**2
    Q_l[0,0] = Q_l[1,0] + (ms+mt+mh)*l**2 + ms*a1**2 + mt*(a2+ls)**2

    q_r = [state[1],state[3]]
    rhs = np.dot(Q_r,q_r)
    sol = np.linalg.solve(Q_l,rhs)

    xd = np.zeros_like(state)
    xd[0] = state[2]
    xd[1] = sol[0]
    xd[2] = state[0]
    xd[3] = sol[1]
    xd[4] = state[0]
    xd[5] = sol[1]

    return xd

def knee_strike(state):
    q1 = state[0]
    q2 = state[2]
    q3 = state[4]

    alpha = cos(q1-q2)
    beta = cos(q1-q3)
    gamma = cos(q2-q3)

    Q_r = np.zeros((2,3))
    Q_r[0,0] = -(ms*lt+mt*b2)*l*cos(alpha) - ms*b1*l*cos(beta) + (mt+ms+mh)*l**2 + ms*a1**2 + mt*(ls+a2)**2
    Q_r[0,1] = -(ms*lt+mt*b2)*l*cos(alpha) + ms*b1*lt*cos(gamma) + mt*b2**2 + ms*lt**2
    Q_r[0,2] = -ms*b1*l*cos(beta) + ms*b1*lt*cos(gamma) + ms*b1**2
    Q_r[1,0] = -(ms*lt+mt*b2)*l*cos(alpha) - ms*b1*l*cos(beta)
    Q_r[1,1] = ms*b1*lt*cos(gamma) + ms*lt**2 + mt*b2**2
    Q_r[1,2] = ms*b1*lt*cos(gamma) + ms*b1**2

    Q_l = np.zeros((2,2))
    Q_l[1,1] = ms*(lt+b1)**2 + mt*b2**2
    Q_l[1,0] = -(ms*(b1+lt) + mt*b2) * l*cos(alpha)
    Q_l[0,1] = Q_l[1,0] + ms*(lt+b1)**2 + mt*b2**2
    Q_l[0,0] = Q_l[1,0] + mt*(ls+a2)**2 + (mh+mt+ms)*l**2 + ms*a1**2

    q_r = [state[1],state[3],state[5]]
    rhs = np.dot(Q_r,q_r)
    sol = np.linalg.solve(Q_l,rhs)

    xd = np.zeros_like(state)
    xd[0] = state[1]
    xd[1] = sol[0]
    xd[2] = state[3]
    xd[3] = sol[1]
    xd[4] = state[5]
    xd[5] = sol[1]  # q3d = q2d, thigh and shank binded

    return xd


def step_cycle(state,_time):
    print('initial position')
    print(np.degrees([state[0],state[2],state[4]]))

    ttcosd = []
    cnt = 0
    num_time = 2
    dt = _time / num_time
    chain_num=3 # starts with three-chain state
    while cnt<300:
        print('cnt: ',cnt)
        t = np.arange(0.0, _time, dt)
        if cnt==0:
            tmp = integrate.odeint(three_linked_chain, state, t)
            state = np.insert(tmp[1:len(tmp)+1],[0],state,axis=0)
            print('three linked chain, time: %s <<<' % (cnt*_time))
            print(np.degrees([state[-1,0],state[-1,2],state[-1,4]]))
            cnt += 1
            continue
        # knee strike
        if  (np.max(-(state[-num_time:,2]))>np.radians(_alpha/2-_gamma)*0.9)\
        and (chain_num==3) and (np.min(np.abs(state[-num_time:,2]-state[-num_time:,4]))<np.radians(1)):
            tmp = knee_strike(state[-1])
            # state = np.insert(tmp,[0],state,axis=0)
            chain_num = 2
            print('===============================================knee strike, time: %s' % (cnt*_time))
            print(np.degrees([state[-1,0],state[-1,2],state[-1,4]]))
            np.insert(tmp,[0],state,axis=1)
            continue
        # heel strike
        if (chain_num==2) and cosd<(3): # in degree
            tmp = heel_strike(state[-1])
            # state = np.insert(tmp,[0],state,axis=0)
            chain_num = 3
            print('===============================================heel strike, time: %s' % (cnt*_time))
            print(np.degrees([state[-1,0],state[-1,2],state[-1,4]]))
            # switching nonstance leg and stance leg at this moment
            # continue
            break
        # three linked chain
        if (chain_num==3):
            tmp = integrate.odeint(three_linked_chain, state[-1], t)
            state = np.insert(tmp[1:len(tmp)+1],[0],state,axis=0)
            print('three linked chain, time: %s <<<' % (cnt*_time))
            print(np.degrees([state[-1,0],state[-1,2],state[-1,4]]))
            chain_num = 3
            cnt += 1
        # two linked chain
        if (chain_num==2):
            tmp = integrate.odeint(two_linked_chain, state[-1], t)
            state = np.insert(tmp[1:len(tmp)+1],[0],state,axis=0)
            print('two linked chain, time: %s <<<' % (cnt*_time))
            print(np.degrees([state[-1,0],state[-1,2],state[-1,4]]))
            chain_num = 2
            cnt += 1

        q1 = tmp[:,0]
        q2 = tmp[:,2]
        q3 = tmp[:,4]
        x_h_tmp = -l*sin(q1)
        y_h_tmp = l*cos(q1)
        x_nsk_tmp = x_h_tmp - lt*sin(q2)
        y_nsk_tmp = y_h_tmp - lt*cos(q2)
        x_nsf_tmp = x_nsk_tmp - ls*sin(q3)
        y_nsf_tmp = y_nsk_tmp - ls*cos(q3)

        v1 = [(x_nsf_tmp[i],y_nsf_tmp[i]) for i in range(num_time)]
        v2 = [cos(np.radians(_gamma)),-sin(np.radians(_gamma))]
        ab = np.dot(v1, v2)
        print(ab)
        cosd = [np.degrees(math.acos( 0.999* ab[i] / np.linalg.norm((x_nsf_tmp[i],y_nsf_tmp[i])))) for i in range(num_time)]
        # tmp = ab / np.linalg.norm([x_nsf_tmp,y_nsf_tmp])
        # cosd = [np.degrees(math.acos(tmp[0]))]
        ttcosd = ttcosd + (cosd)
        cosd = min(np.abs(cosd))
        print('cosd: ',cosd)
        print('chain_num: ',chain_num)

    q1 = state[:,0]
    q2 = state[:,2]
    q3 = state[:,4]
    x_h = -l*sin(q1)
    y_h = l*cos(q1)
    x_nsk = x_h - lt*sin(q2)
    y_nsk = y_h - lt*cos(q2)
    x_nsf = x_nsk - ls*sin(q3)
    y_nsf = y_nsk - ls*cos(q3)

    return x_h,y_h,x_nsk,y_nsk,x_nsf,y_nsf,state[-1,:]

def init():
    for line in lines:
        line.set_data([],[])
    time_text.set_text('')
    return tuple(lines) + (time_text,)


def animate(i):

    x_bipedal = [0, x_h[i], x_nsk[i], x_nsf[i]]
    y_bipedal = [0, y_h[i], y_nsk[i], y_nsf[i]]
    # x_bipedal = [0, x_h[-10], x_nsk[-10], x_nsf[-10]]
    # y_bipedal = [0, y_h[-10], y_nsk[-10], y_nsf[-10]]

    x_slop = [x_slop_up,x_slop_low,-2]
    y_slop = [y_slop_up,y_slop_low,y_slop_low]

    xlist = [x_bipedal, x_slop]
    ylist = [y_bipedal, y_slop]

    for lnum,line in enumerate(lines):
        line.set_data(xlist[lnum], ylist[lnum]) # set data for each line separately.

    time_text.set_text(time_template % (i*dt))

    return tuple(lines) + (time_text,)



# Passive Dynamic Walking for bipedal robot
# % reset

from numpy import sin, cos
import numpy as np
import scipy.integrate as integrate
import math

# parameters of leg structure
mt = 0.5  # mass of thigh
ms = 0.05  # mass of shank
mh = 0.5   #mass of hip
a1 = 0.375
b1 = 0.125
a2 = 0.175
b2 = 0.325
lt = a2 + b2  # length of thigh
ls = a1 + b1  # length of shank
l = lt + ls

g = 9.8  # acceleration due to gravity, in m/s^2
dt = 0.01 # time step of simulation

# slop of terran
_gamma = (9)
x_slop_low = 2 * cos(np.radians(_gamma))
x_slop_up = -x_slop_low
y_slop_low = -2 * sin(np.radians(_gamma))
y_slop_up = -y_slop_low


# initial states, defined by angle between two legs
_alpha = (20)
q1 = _alpha/2 - _gamma
q1d = 0.0
q2 = _alpha/2 + _gamma
q2d = 0.0
q3 = q2
q3d = 0.0
state = np.radians([q1, q1d, q2, q2d, q3, q3d])

x_h, y_h, x_nsk, y_nsk, x_nsf, y_nsf,state = step_cycle(state, dt)
# for i in range(2):
#     x_h_, y_h_, x_nsk_, y_nsk_, x_nsf_, y_nsf_, state = step_cycle(state, dt)
#     x_h.append(x_h_)

# f = open('out.txt', 'w')
# f.write(str(x_h))
# f.write(str(state))
# f.write('\n')


import matplotlib.pyplot as plt
# from numpy import random
import matplotlib.animation as animation
fig = plt.figure()
ax1 = plt.axes(xlim=(-2, 2), ylim=(-2,2))
ax1.grid(True)
plt.xlabel('Longitude')
plt.ylabel('Latitude')

lines = []
lobj = ax1.plot([],[],'o-',lw=2,color="black")[0]
lines.append(lobj)
lobj = ax1.plot([],[],lw=2,color="red")[0]
lines.append(lobj)

time_template = 'time = %.3fs'
time_text = ax1.text(0.05, 0.9, '', transform=ax1.transAxes)

print('hello')

# call the animator.  blit=True means only re-draw the parts that have changed.
# ani = animation.FuncAnimation(fig, animate, init_func=init,
#                                frames=300, interval=10, blit=True)

ani = animation.FuncAnimation(fig, animate, np.arange(1, len(x_h)),
                              interval=50, blit=True, init_func=init)
plt.show()
# ani.save('PDW.mp4', fps=15)
# Out:
# initial position
# [  1.  19.  19.]
# cnt:  0
# three linked chain, time: 0.0 <<<
# [  0.99870072  18.98916773  19.0151608 ]
# cnt:  1
# three linked chain, time: 0.01 <<<
# [  0.99480318  18.95668187  19.06057574]
# [-0.34731122 -0.34735527]
# cosd:  177.437431768
# chain_num:  3
# cnt:  2
# three linked chain, time: 0.02 <<<
# [  0.98830826  18.90257526  19.13604255]
# [-0.34735527 -0.34742691]
# cosd:  177.43739236
# chain_num:  3
# cnt:  3
# three linked chain, time: 0.03 <<<
# [  0.97921744  18.82690265  19.24122493]
# [-0.34742691 -0.34752345]
# cosd:  177.437283066
# chain_num:  3
# cnt:  4
# three linked chain, time: 0.04 <<<
# [  0.96753286  18.72974072  19.37565392]
# [-0.34752345 -0.3476412 ]
# cosd:  177.437043625
# chain_num:  3
# cnt:  5
# three linked chain, time: 0.05 <<<
# [  0.95325737  18.61118809  19.53872968]
# [-0.3476412 -0.3477754]
# cosd:  177.436587778
# chain_num:  3
# cnt:  6
# three linked chain, time: 0.06 <<<
# [  0.93639458  18.47136534  19.72972375]
# [-0.3477754  -0.34792032]
# cosd:  177.435796702
# chain_num:  3
# cnt:  7
# three linked chain, time: 0.07 <<<
# [  0.91694895  18.31041506  19.94778194]
# [-0.34792032 -0.34806925]
# cosd:  177.43451108
# chain_num:  3
# cnt:  8
# three linked chain, time: 0.08 <<<
# [  0.89492588  18.12850186  20.19192748]
# [-0.34806925 -0.34821455]
# cosd:  177.432521973
# chain_num:  3
# cnt:  9
# three linked chain, time: 0.09 <<<
# [  0.87033183  17.92581245  20.4610648 ]
# [-0.34821455 -0.3483477 ]
# cosd:  177.429560737
# chain_num:  3
# cnt:  10
# three linked chain, time: 0.1 <<<
# [  0.84317445  17.70255563  20.75398381]
# [-0.3483477  -0.34845936]
# cosd:  177.425288433
# chain_num:  3
# cnt:  11
# three linked chain, time: 0.11 <<<
# [  0.81346266  17.45896243  21.069364  ]
# [-0.34845936 -0.34853939]
# cosd:  177.419285302
# chain_num:  3
# cnt:  12
# three linked chain, time: 0.12 <<<
# [  0.78120687  17.1952861   21.4057798 ]
# [-0.34853939 -0.34857695]
# cosd:  177.411041094
# chain_num:  3
# cnt:  13
# three linked chain, time: 0.13 <<<
# [  0.74641907  16.91180217  21.76170565]
# [-0.34857695 -0.34856054]
# cosd:  177.399947251
# chain_num:  3
# cnt:  14
# three linked chain, time: 0.14 <<<
# [  0.709113    16.60880854  22.13552166]
# [-0.34856054 -0.34847809]
# cosd:  177.385292144
# chain_num:  3
# cnt:  15
# three linked chain, time: 0.15 <<<
# [  0.66930433  16.2866255   22.52551944]
# [-0.34847809 -0.34831702]
# cosd:  177.36626065
# chain_num:  3
# cnt:  16
# three linked chain, time: 0.16 <<<
# [  0.62701085  15.94559576  22.92990821]
# [-0.34831702 -0.34806433]
# cosd:  177.341939375
# chain_num:  3
# cnt:  17
# three linked chain, time: 0.17 <<<
# [  0.58225258  15.58608454  23.3468211 ]
# [-0.34806433 -0.34770666]
# cosd:  177.311328625
# chain_num:  3
# cnt:  18
# three linked chain, time: 0.18 <<<
# [  0.53505199  15.20847952  23.77432164]
# [-0.34770666 -0.34723041]
# cosd:  177.273361777
# chain_num:  3
# cnt:  19
# three linked chain, time: 0.19 <<<
# [  0.48543416  14.81319085  24.21041054]
# [-0.34723041 -0.34662179]
# cosd:  177.226931934
# chain_num:  3
# cnt:  20
# three linked chain, time: 0.2 <<<
# [  0.43342694  14.40065117  24.65303183]
# [-0.34662179 -0.34586692]
# cosd:  177.170924955
# chain_num:  3
# cnt:  21
# three linked chain, time: 0.21 <<<
# [  0.37906111  13.97131546  25.10008019]
# [-0.34586692 -0.3449519 ]
# cosd:  177.104256578
# chain_num:  3
# cnt:  22
# three linked chain, time: 0.22 <<<
# [  0.32237052  13.52566094  25.54940752]
# [-0.3449519  -0.34386293]
# cosd:  177.025910819
# chain_num:  3
# cnt:  23
# three linked chain, time: 0.23 <<<
# [  0.26339223  13.06418693  25.99882953]
# [-0.34386293 -0.34258633]
# cosd:  176.934976093
# chain_num:  3
# cnt:  24
# three linked chain, time: 0.24 <<<
# [  0.20216662  12.58741458  26.44613257]
# [-0.34258633 -0.34110867]
# cosd:  176.830675493
# chain_num:  3
# cnt:  25
# three linked chain, time: 0.25 <<<
# [  0.1387375   12.09588655  26.88908028]
# [-0.34110867 -0.33941681]
# cosd:  176.712388462
# chain_num:  3
# cnt:  26
# three linked chain, time: 0.26 <<<
# [  0.07315217  11.59016665  27.32541996]
# [-0.33941681 -0.33749796]
# cosd:  176.579662257
# chain_num:  3
# cnt:  27
# three linked chain, time: 0.27 <<<
# [  5.46149331e-03   1.10708394e+01   2.77528888e+01]
# [-0.33749796 -0.33533976]
# cosd:  176.432212876
# chain_num:  3
# cnt:  28
# three linked chain, time: 0.28 <<<
# [ -0.0642801   10.53850942  28.16922015]
# [-0.33533976 -0.33293033]
# cosd:  176.269916414
# chain_num:  3
# cnt:  29
# three linked chain, time: 0.29 <<<
# [ -0.13601462   9.99380083  28.57214918]
# [-0.33293033 -0.33025827]
# cosd:  176.092792698
# chain_num:  3
# cnt:  30
# three linked chain, time: 0.3 <<<
# [ -0.2096805    9.43735641  28.95941897]
# [-0.33025827 -0.32731273]
# cosd:  175.900983484
# chain_num:  3
# cnt:  31
# three linked chain, time: 0.31 <<<
# [ -0.28521275   8.86983673  29.32878581]
# [-0.32731273 -0.32408345]
# cosd:  175.694727337
# chain_num:  3
# cnt:  32
# three linked chain, time: 0.32 <<<
# [ -0.36254299   8.29191915  29.67802453]
# [-0.32408345 -0.32056071]
# cosd:  175.474333017
# chain_num:  3
# cnt:  33
# three linked chain, time: 0.33 <<<
# [ -0.4415996    7.70429678  30.00493317]
# [-0.32056071 -0.3167354 ]
# cosd:  175.240152684
# chain_num:  3
# cnt:  34
# three linked chain, time: 0.34 <<<
# [ -0.52230789   7.1076773   30.30733759]
# [-0.3167354  -0.31259897]
# cosd:  174.992555338
# chain_num:  3
# cnt:  35
# three linked chain, time: 0.35000000000000003 <<<
# [ -0.60459034   6.50278127  30.58309693]
# [-0.31259897 -0.30814345]
# cosd:  174.731900052
# chain_num:  3
# cnt:  36
# three linked chain, time: 0.36 <<<
# [ -0.68836677   5.89034102  30.83010673]
# [-0.30814345 -0.30336137]
# cosd:  174.458510084
# chain_num:  3
# cnt:  37
# three linked chain, time: 0.37 <<<
# [ -0.77355468   5.27109896  31.04630316]
# [-0.30336137 -0.29824581]
# cosd:  174.172645584
# chain_num:  3
# cnt:  38
# three linked chain, time: 0.38 <<<
# [ -0.86006948   4.64580596  31.22966658]
# [-0.29824581 -0.29279028]
# cosd:  173.874474571
# chain_num:  3
# cnt:  39
# three linked chain, time: 0.39 <<<
# [ -0.94782485   4.01521957  31.37822492]
# [-0.29279028 -0.28698874]
# cosd:  173.56404072
# chain_num:  3
# cnt:  40
# three linked chain, time: 0.4 <<<
# [ -1.0367331    3.38010225  31.49005676]
# [-0.28698874 -0.28083549]
# cosd:  173.241226281
# chain_num:  3
# cnt:  41
# three linked chain, time: 0.41000000000000003 <<<
# [ -1.12670549   2.74121946  31.56329418]
# [-0.28083549 -0.27432515]
# cosd:  172.905708106
# chain_num:  3
# cnt:  42
# three linked chain, time: 0.42 <<<
# [ -1.21765263   2.09933789  31.59612513]
# [-0.27432515 -0.26745261]
# cosd:  172.556904337
# chain_num:  3
# cnt:  43
# three linked chain, time: 0.43 <<<
# [ -1.30948493   1.45522314  31.58679675]
# [-0.26745261 -0.26021293]
# cosd:  172.193907386
# chain_num:  3
# cnt:  44
# three linked chain, time: 0.44 <<<
# [ -1.40211292   0.80963812  31.53361663]
# [-0.26021293 -0.25260133]
# cosd:  171.815400726
# chain_num:  3
# cnt:  45
# three linked chain, time: 0.45 <<<
# [ -1.49544767   0.16334104  31.43495533]
# [-0.25260133 -0.2446131 ]
# cosd:  171.419551142
# chain_num:  3
# cnt:  46
# three linked chain, time: 0.46 <<<
# [ -1.58940124  -0.48291659  31.28924832]
# [-0.2446131  -0.23624354]
# cosd:  171.003868946
# chain_num:  3
# cnt:  47
# three linked chain, time: 0.47000000000000003 <<<
# [ -1.68388699  -1.12839178  31.0949979 ]
# [-0.23624354 -0.22748796]
# cosd:  170.565023583
# chain_num:  3
# cnt:  48
# three linked chain, time: 0.48 <<<
# [ -1.77882002  -1.7723519   30.85077504]
# [-0.22748796 -0.21834158]
# cosd:  170.098596777
# chain_num:  3
# cnt:  49
# three linked chain, time: 0.49 <<<
# [ -1.87411751  -2.41407638  30.5552212 ]
# [-0.21834158 -0.20879954]
# cosd:  169.598746779
# chain_num:  3
# cnt:  50
# three linked chain, time: 0.5 <<<
# [ -1.96969905  -3.05285835  30.20705018]
# [-0.20879954 -0.19885688]
# cosd:  169.057743828
# chain_num:  3
# cnt:  51
# three linked chain, time: 0.51 <<<
# [ -2.06548692  -3.68800617  29.80505002]
# [-0.19885688 -0.1885085 ]
# cosd:  168.465315191
# chain_num:  3
# cnt:  52
# three linked chain, time: 0.52 <<<
# [ -2.16140644  -4.31884482  29.34808497]
# [-0.1885085  -0.17774921]
# cosd:  167.8077023
# chain_num:  3
# cnt:  53
# three linked chain, time: 0.53 <<<
# [ -2.25738614  -4.94471709  28.83509762]
# [-0.17774921 -0.1665737 ]
# cosd:  167.066271648
# chain_num:  3
# cnt:  54
# three linked chain, time: 0.54 <<<
# [ -2.35335801  -5.56498474  28.26511109]
# [-0.1665737  -0.15497663]
# cosd:  166.215414391
# chain_num:  3
# cnt:  55
# three linked chain, time: 0.55 <<<
# [ -2.44925763  -6.17902955  27.63723179]
# [-0.15497663 -0.14295268]
# cosd:  165.219275882
# chain_num:  3
# cnt:  56
# three linked chain, time: 0.56 <<<
# [ -2.5450243   -6.78625353  26.95065112]
# [-0.14295268 -0.13049658]
# cosd:  164.026494627
# chain_num:  3
# cnt:  57
# three linked chain, time: 0.5700000000000001 <<<
# [ -2.64060111  -7.38608003  26.2046492 ]
# [-0.13049658 -0.11760329]
# cosd:  162.561408787
# chain_num:  3
# cnt:  58
# three linked chain, time: 0.58 <<<
# [ -2.73593496  -7.97795398  25.39859761]
# [-0.11760329 -0.10426802]
# cosd:  160.708728068
# chain_num:  3
# cnt:  59
# three linked chain, time: 0.59 <<<
# [ -2.83097656  -8.56134199  24.53196262]
# [-0.10426802 -0.09048646]
# cosd:  158.285507486
# chain_num:  3
# cnt:  60
# three linked chain, time: 0.6 <<<
# [ -2.92568036  -9.13573242  23.60430869]
# [-0.09048646 -0.07625488]
# cosd:  154.987220666
# chain_num:  3
# cnt:  61
# three linked chain, time: 0.61 <<<
# [ -3.02000438  -9.70063516  22.61530209]
# [-0.07625488 -0.06157033]
# cosd:  150.278931228
# chain_num:  3
# cnt:  62
# three linked chain, time: 0.62 <<<
# [ -3.11391011 -10.25558121  21.56471478]
# [-0.06157033 -0.04643083]
# cosd:  143.171533949
# chain_num:  3
# cnt:  63
# three linked chain, time: 0.63 <<<
# [ -3.20736228 -10.8001222   20.45242836]
# [-0.04643083 -0.03083562]
# cosd:  131.814014212
# chain_num:  3
# cnt:  64
# three linked chain, time: 0.64 <<<
# [ -3.30032857 -11.33382955  19.2784382 ]
# [-0.03083562 -0.01478534]
# cosd:  113.33184776
# chain_num:  3
# cnt:  65
# three linked chain, time: 0.65 <<<
# [ -3.39277941 -11.85629363  18.04285757]
# [-0.01478534  0.0017177 ]
# cosd:  87.1268783808
# chain_num:  3
# cnt:  66
# three linked chain, time: 0.66 <<<
# [ -3.48468755 -12.36712268  16.74592181]
# [ 0.0017177   0.01866926]
# cosd:  61.4722213616
# chain_num:  3
# cnt:  67
# three linked chain, time: 0.67 <<<
# [ -3.57602777 -12.86594165  15.38799243]
# [ 0.01866926  0.03606292]
# cosd:  43.8720003921
# chain_num:  3
# cnt:  68
# three linked chain, time: 0.68 <<<
# [ -3.66677649 -13.35239068  13.96956128]
# [ 0.03606292  0.0538898 ]
# cosd:  33.1796369158
# chain_num:  3
# cnt:  69
# three linked chain, time: 0.6900000000000001 <<<
# [ -3.75691135 -13.82612419  12.49125404]
# [ 0.0538898   0.07213835]
# cosd:  26.5728141973
# chain_num:  3
# cnt:  70
# three linked chain, time: 0.7000000000000001 <<<
# [ -3.84641081 -14.28680889  10.95383403]
# [ 0.07213835  0.09079404]
# cosd:  22.3008077838
# chain_num:  3
# cnt:  71
# three linked chain, time: 0.71 <<<
# [ -3.93525372 -14.73412249   9.35820545]
# [ 0.09079404  0.10983918]
# cosd:  19.4301066835
# chain_num:  3
# cnt:  72
# three linked chain, time: 0.72 <<<
# [ -4.02341889 -15.16775204   7.70541627]
# [ 0.10983918  0.12925266]
# cosd:  17.4529638631
# chain_num:  3
# cnt:  73
# three linked chain, time: 0.73 <<<
# [ -4.11088471 -15.5873926    5.99666036]
# [ 0.12925266  0.1490098 ]
# cosd:  16.0781027588
# chain_num:  3
# cnt:  74
# three linked chain, time: 0.74 <<<
# [ -4.19762872 -15.99274535   4.23328059]
# [ 0.1490098   0.16908217]
# cosd:  15.1290523085
# chain_num:  3
# cnt:  75
# three linked chain, time: 0.75 <<<
# [ -4.28362726 -16.38351657   2.41676941]
# [ 0.16908217  0.18943752]
# cosd:  14.4935655786
# chain_num:  3
# cnt:  76
# three linked chain, time: 0.76 <<<
# [ -4.36885514 -16.75941619   0.54877023]
# [ 0.18943752  0.21003965]
# cosd:  14.0971884598
# chain_num:  3
# cnt:  77
# three linked chain, time: 0.77 <<<
# [ -4.45328535 -17.12015672  -1.36892208]
# [ 0.21003965  0.23084846]
# cosd:  13.8887147387
# chain_num:  3
# cnt:  78
# three linked chain, time: 0.78 <<<
# [ -4.53688885 -17.46545228  -3.33436117]
# [ 0.23084846  0.25181997]
# cosd:  13.8317895183
# chain_num:  3
# cnt:  79
# three linked chain, time: 0.79 <<<
# [ -4.61963435 -17.79501793  -5.34544958]
# [ 0.25181997  0.27290641]
# cosd:  13.8317895183
# chain_num:  3
# cnt:  80
# three linked chain, time: 0.8 <<<
# [ -4.70148825 -18.10856924  -7.39993965]
# [ 0.27290641  0.29405642]
# cosd:  13.8998522069
# chain_num:  3
# cnt:  81
# three linked chain, time: 0.81 <<<
# [ -4.78241459 -18.40582217  -9.49543485]
# [ 0.29405642  0.31521525]
# cosd:  14.0729774034
# chain_num:  3
# cnt:  82
# three linked chain, time: 0.8200000000000001 <<<
# [ -4.86237512 -18.68649326 -11.62939137]
# [ 0.31521525  0.33632512]
# cosd:  14.3358390285
# chain_num:  3
# cnt:  83
# three linked chain, time: 0.8300000000000001 <<<
# [ -4.9413294  -18.95030025 -13.79912012]
# [ 0.33632512  0.35732553]
# cosd:  14.6763632556
# chain_num:  3
# cnt:  84
# three linked chain, time: 0.84 <<<
# [ -5.01923509 -19.19696295 -16.00178896]
# [ 0.35732553  0.37815373]
# cosd:  15.0848168868
# chain_num:  3
# cnt:  85
# three linked chain, time: 0.85 <<<
# [ -5.09604819 -19.42620463 -18.23442541]
# [ 0.37815373  0.39874525]
# cosd:  15.5531781822
# chain_num:  3
# cnt:  86
# three linked chain, time: 0.86 <<<
# [ -5.17172352 -19.63775367 -20.49391949]
# [ 0.39874525  0.41903441]
# cosd:  16.0746950328
# chain_num:  3
# cnt:  87
# ===============================================knee strike, time: 0.87
# [ -5.17172352 -19.63775367 -20.49391949]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-5c5014b3db25> in <module>()
#     323 state = np.radians([q1, q1d, q2, q2d, q3, q3d])
#     324
# --> 325 x_h, y_h, x_nsk, y_nsk, x_nsf, y_nsf,state = step_cycle(state, dt)
#     326 # for i in range(2):
#     327 #     x_h_, y_h_, x_nsk_, y_nsk_, x_nsf_, y_nsf_, state = step_cycle(state, dt)
#
# <ipython-input-4-5c5014b3db25> in step_cycle(state, _time)
#     190             print('===============================================knee strike, time: %s' % (cnt*_time))
#     191             print(np.degrees([state[-1,0],state[-1,2],state[-1,4]]))
# --> 192             np.insert(tmp,[0],state,axis=1)
#     193             continue
#     194         # heel strike
#
# /home/hope-yao/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py in insert(arr, obj, values, axis)
#    3992             raise IndexError(
#    3993                 "axis %i is out of bounds for an array of "
# -> 3994                 "dimension %i" % (axis, ndim))
#    3995         if (axis < 0):
#    3996             axis += ndim
#
# IndexError: axis 1 is out of bounds for an array of dimension 1

# %%
tmp = np.array([1,2])
tt = np.array([[11,12],[13,14]])
np.insert(tt,[0],tmp,axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-4700df509c83> in <module>()
#       1 tmp = np.array([1,2])
#       2 tt = np.array([[11,12],[13,14]])
# ----> 3 np.insert(tmp,[0],tt,axis=0)
#
# /home/hope-yao/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py in insert(arr, obj, values, axis)
#    4055         new[slobj] = arr[slobj]
#    4056         slobj[axis] = slice(index, index+numnew)
# -> 4057         new[slobj] = values
#    4058         slobj[axis] = slice(index+numnew, None)
#    4059         slobj2 = [slice(None)] * ndim
#
# ValueError: could not broadcast input array from shape (2,2) into shape (2)

# %%
a = np.array([[1, 1], [2, 2], [3, 3]])
np.insert(a, [0], [[10],[20]], axis=0)
# np.array_equal(np.insert(a, 1, [1, 2, 3], axis=1),
#                 np.insert(a, [1], [[1],[2],[3]], axis=1))
# Out:
# array([[10, 10],
#        [20, 20],
#        [ 1,  1],
#        [ 2,  2],
#        [ 3,  3]])
